# %%
import numpy as np
import pandas as pd 
import seaborn as sns

# %%
#Uploading datasets
testSet = pd.read_csv("test.csv")
testSet.set_index('PassengerId',inplace=True)
trainingSet = pd.read_csv("train.csv")
trainingSet.set_index('PassengerId',inplace=True)

trainingSet.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
#Exploratory Data Analysis

#Univariate statistics
nb_passagers = 891
survivors = trainingSet[trainingSet['Survived'] == 1]['Survived'].count()
deaths = trainingSet[trainingSet['Survived'] == 0]['Survived'].count()


print("Number of passengers registered : "+str(nb_passagers))
print("Number of survivors : "+str(survivors))
print("Number of deaths : "+str(deaths))
print("Survival rate : "+str(survivors*100/(survivors+deaths))+"%")

sns.countplot(x=trainingSet["Survived"])
# Out:
# Number of passengers registered : 891
# Number of survivors : 342
# Number of deaths : 549
# Survival rate : 38.38383838383838%
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
firstClass = trainingSet[trainingSet['Pclass'] == 1]['Pclass'].count()
secondClass = trainingSet[trainingSet['Pclass'] == 2]['Pclass'].count()
thirdClass = trainingSet[trainingSet['Pclass'] == 3]['Pclass'].count()
classTotal = trainingSet['Pclass'].count()

print("Number of first class passengers : "+str(firstClass)+ " (" + str(firstClass*100/classTotal) + "% of the passengers)")
print("Number of second class passengers : "+str(secondClass)+ " (" + str(secondClass*100/classTotal) + "% of the passengers)")
print("Number of third class passengers : "+str(thirdClass)+ " (" + str(thirdClass*100/classTotal) + "% of the passengers)")

sns.countplot(x=trainingSet["Pclass"])
# Out:
# Number of first class passengers : 216 (24.242424242424242% of the passengers)
# Number of second class passengers : 184 (20.650953984287316% of the passengers)
# Number of third class passengers : 491 (55.10662177328844% of the passengers)
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %%
male = trainingSet[trainingSet['Sex'] == 'male']['Sex'].count()
female = trainingSet[trainingSet['Sex'] == 'female']['Sex'].count()

print("Number of male passengers : "+str(male)+ " (" + str(male*100/nb_passagers) + "% of the passengers)")
print("Number of female passengers : "+str(female)+ " (" + str(female*100/nb_passagers) + "% of the passengers)")

sns.countplot(x=trainingSet["Sex"])
# Out:
# Number of male passengers : 577 (64.75869809203142% of the passengers)
# Number of female passengers : 314 (35.24130190796858% of the passengers)
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
print("Age of the passengers :")
trainingSet["Age"].describe()
# Out:
# Age of the passengers :
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
sns.histplot(trainingSet["Age"],bins=6)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
print("Number of siblings / spouses aboard the Titanic :")
trainingSet["SibSp"].describe()
# Out:
# Number of siblings / spouses aboard the Titanic :
# count    891.000000
# mean       0.523008
# std        1.102743
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        8.000000
# Name: SibSp, dtype: float64

# %%
sns.countplot(x=trainingSet["SibSp"])
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='count'>

# %%
print("Number of parents / children aboard the Titanic :")
trainingSet["Parch"].describe()
# Out:
# Number of parents / children aboard the Titanic :
# count    891.000000
# mean       0.381594
# std        0.806057
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        6.000000
# Name: Parch, dtype: float64

# %%
sns.countplot(x=trainingSet["Parch"])
# Out:
# <AxesSubplot:xlabel='Parch', ylabel='count'>

# %%
print("Ticket fare :")
trainingSet["Fare"].describe()
# Out:
# Ticket fare :
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
sns.histplot(x=trainingSet["Fare"])
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Count'>

# %%
Cherbourg = trainingSet[trainingSet['Embarked'] == "C"]['Embarked'].count()
Queenstown = trainingSet[trainingSet['Embarked'] == "Q"]['Embarked'].count()
Southampton = trainingSet[trainingSet['Embarked'] == "S"]['Embarked'].count()


print("Number of passagers who embarked from Cherbourg : "+str(Cherbourg)+ " (" + str(Cherbourg*100/nb_passagers) + "% of the passengers)")
print("Number of passagers who embarked from Queenstown : "+str(Queenstown)+ " (" + str(Queenstown*100/nb_passagers) + "% of the passengers)")
print("Number of passagers who embarked from Southampton : "+str(Southampton)+ " (" + str(Southampton*100/nb_passagers) + "% of the passengers)")

sns.countplot(x=trainingSet["Embarked"])
# Out:
# Number of passagers who embarked from Cherbourg : 168 (18.855218855218855% of the passengers)
# Number of passagers who embarked from Queenstown : 77 (8.641975308641975% of the passengers)
# Number of passagers who embarked from Southampton : 644 (72.27833894500561% of the passengers)
# <AxesSubplot:xlabel='Embarked', ylabel='count'>

# %%
#Coding quantitative variables
#sex : 0 if male, 1 if female
trainingSet.loc[trainingSet['Sex']=='male','Sex'] = 0
trainingSet.loc[trainingSet['Sex']=='female','Sex'] = 1
testSet.loc[testSet['Sex']=='male','Sex'] = 0
testSet.loc[testSet['Sex']=='female','Sex'] = 1

#Classes, creating a boolean column for each
trainingSet['First Class'] = trainingSet['Pclass'].apply(lambda x: 1 if x==1 else 0)
trainingSet['Second Class'] = trainingSet['Pclass'].apply(lambda x: 1 if x==2 else 0)
trainingSet['Third Class'] = trainingSet['Pclass'].apply(lambda x: 1 if x==3 else 0)


testSet['First Class'] = testSet['Pclass'].apply(lambda x: 1 if x==1 else 0)
testSet['Second Class'] = testSet['Pclass'].apply(lambda x: 1 if x==2 else 0)
testSet['Third Class'] = testSet['Pclass'].apply(lambda x: 1 if x==3 else 0)

#Embarked

trainingSet['Southampton'] = trainingSet['Embarked'].apply(lambda x: 1 if x=='S' else 0)
trainingSet['Queenstown'] = trainingSet['Embarked'].apply(lambda x: 1 if x=='Q' else 0)
trainingSet['Cherbourg'] = trainingSet['Embarked'].apply(lambda x: 1 if x=='C' else 0)


testSet['Southampton'] = testSet['Embarked'].apply(lambda x: 1 if x=='S' else 0)
testSet['Queenstown'] = testSet['Embarked'].apply(lambda x: 1 if x=='Q' else 0)
testSet['Cherbourg'] = testSet['Embarked'].apply(lambda x: 1 if x=='C' else 0)

trainingSet.loc[trainingSet['Embarked']=='S','Embarked'] = 1
trainingSet.loc[trainingSet['Embarked']=='Q','Embarked'] = 2
trainingSet.loc[trainingSet['Embarked']=='C','Embarked'] = 3


testSet.loc[testSet['Embarked']=='S','Embarked'] = 1
testSet.loc[testSet['Embarked']=='Q','Embarked'] = 2
testSet.loc[testSet['Embarked']=='C','Embarked'] = 3

#Age
trainingSet['Young (0-20 years old)'] = trainingSet['Age'].apply(lambda x: 1 if x<=20.125 else 0)
trainingSet['Young Adult (20-28 years old)'] = trainingSet['Age'].apply(lambda x: 1 if x>20.125 and x<=28 else 0)
trainingSet['Adult (28-38 years old)'] = trainingSet['Age'].apply(lambda x: 1 if x>28 and x<=38 else 0)
trainingSet['Old (38+ years old)'] = trainingSet['Age'].apply(lambda x: 1 if x>38  else 0)

testSet['Young (0-20 years old)'] = testSet['Age'].apply(lambda x: 1 if x<=20.125 else 0)
testSet['Young Adult (20-28 years old)'] = testSet['Age'].apply(lambda x: 1 if x>20.125 and x<=28 else 0)
testSet['Adult (28-38 years old)'] = testSet['Age'].apply(lambda x: 1 if x>28 and x<=38 else 0)
testSet['Old (38+ years old)'] = testSet['Age'].apply(lambda x: 1 if x>38  else 0)

#Siblings
trainingSet['Have Siblings'] = trainingSet['SibSp'].apply(lambda x: 1 if x>0 else 0)
testSet['Have Siblings'] = testSet['SibSp'].apply(lambda x: 1 if x>0 else 0)

#Parents and chikdren
trainingSet['Have Parents or Children'] = trainingSet['Parch'].apply(lambda x: 1 if x>0 else 0)
testSet['Have Parents or Children'] = testSet['Parch'].apply(lambda x: 1 if x>0 else 0)

#Ticket Fare

trainingSet['Very Cheap (<7.9$)'] = trainingSet['Fare'].apply(lambda x: 1 if x<=7.9104 else 0)
trainingSet['Cheap (7.9-14.45$)'] = trainingSet['Fare'].apply(lambda x: 1 if x>7.9104 and x<=14.4542 else 0)
trainingSet['Normal (14.45-31$)'] = trainingSet['Fare'].apply(lambda x: 1 if x>14.4542 and x<=31 else 0)
trainingSet['Expensive (>31$)'] = trainingSet['Fare'].apply(lambda x: 1 if x>31  else 0)

testSet['Very Cheap (<7.9$)'] = testSet['Fare'].apply(lambda x: 1 if x<=7.9104 else 0)
testSet['Cheap (7.9-14.45$)'] = testSet['Fare'].apply(lambda x: 1 if x>7.9104 and x<=14.4542 else 0)
testSet['Normal (14.45-31$)'] = testSet['Fare'].apply(lambda x: 1 if x>14.4542 and x<=31 else 0)
testSet['Expensive (>31$)'] = testSet['Fare'].apply(lambda x: 1 if x>31  else 0)

# %%
trainingSet.to_csv("codedTrainingSet.csv")
testSet.to_csv("codedTestSet.csv")

# %%
#Multivariate analysis

for column in trainingSet.columns:
    if column != "PassengerId" and column != "Survived" and column != "Name" and column != "Age" and column != "Fare" and column != "SibSp" and column != "Parch" and column != "Ticket" and column != "Cabin":
        print(pd.crosstab(trainingSet["Survived"],trainingSet[column]))
# Out:
# Pclass      1   2    3
# Survived
# 0          80  97  372
# 1         136  87  119
# Sex         0    1
# Survived
# 0         468   81
# 1         109  233
# Embarked   C   Q    S
# Survived
# 0         75  47  427
# 1         93  30  217
# First Class    0    1
# Survived
# 0            469   80
# 1            206  136
# Second Class    0   1
# Survived
# 0             452  97
# 1             255  87
# Third Class    0    1
# Survived
# 0            177  372
# 1            223  119
# Young (0-20 years old)    0   1
# Survived
# 0                       452  97
# 1                       260  82
# Young Adult (20-28 years old)    0    1
# Survived
# 0                              432  117
# 1                              276   66
# Adult (28-38 years old)    0   1
# Survived
# 0                        450  99
# 1                        266  76
# Old (38+ years old)    0    1
# Survived
# 0                    438  111
# 1                    276   66
# Have Siblings    0    1
# ...

# %%
sns.countplot(x=trainingSet["Pclass"],hue=trainingSet["Survived"])
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(x=trainingSet["Sex"],hue=trainingSet["Survived"])
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
sns.countplot(x=trainingSet["Embarked"],hue=trainingSet["Survived"])
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='count'>

# %%
sns.countplot(x=trainingSet["Have Siblings"],hue=trainingSet["Survived"])
# Out:
# <AxesSubplot:xlabel='Have Siblings', ylabel='count'>

# %%
sns.countplot(x=trainingSet["Have Parents or Children"],hue=trainingSet["Survived"])
# Out:
# <AxesSubplot:xlabel='Have Parents or Children', ylabel='count'>

# %%
sns.countplot(x=trainingSet["Very Cheap (<7.9$)"],hue=trainingSet["Survived"])
# Out:
# <AxesSubplot:xlabel='Very Cheap (<7.9$)', ylabel='count'>
